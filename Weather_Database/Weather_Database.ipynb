# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 809

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_dscript})
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | pocone
# Processing Record 9 of Set 1 | helena
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hofn
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | saint-augustin
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | san patricio
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | comodoro rivadavia
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | padang
# Processing Record 29 of Set 1 | sydney
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | itarema
# Processing Record 33 of Set 1 | nioro
# Processing Record 34 of Set 1 | bolton
# Processing Record 35 of Set 1 | labuan
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | santa rosa
# Processing Record 38 of Set 1 | chapais
# Processing Record 39 of Set 1 | ahipara
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | panjakent
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | batemans bay
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | igdir
# Processing Record 2 of Set 2 | kaminskiy
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | guadalajara
# Processing Record 8 of Set 2 | naryan-mar
# Processing Record 9 of Set 2 | tahta
# Processing Record 10 of Set 2 | wattegama
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | iralaya
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | port-gentil
# Processing Record 16 of Set 2 | gat
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | olot
# Processing Record 19 of Set 2 | ahuimanu
# Processing Record 20 of Set 2 | boende
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | miraflores
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | munich
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | kribi
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | sao felix do xingu
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | acapulco
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | dingle
# Processing Record 38 of Set 2 | businga
# Processing Record 39 of Set 2 | maceio
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | lasa
# Processing Record 44 of Set 2 | kinkala
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | port lincoln
# Processing Record 50 of Set 2 | chortomlyk
# Processing Record 1 of Set 3 | kushiro
# Processing Record 2 of Set 3 | herat
# Processing Record 3 of Set 3 | tommot
# Processing Record 4 of Set 3 | sandnessjoen
# Processing Record 5 of Set 3 | skjervoy
# Processing Record 6 of Set 3 | zaranj
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | hobyo
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | sampang
# Processing Record 11 of Set 3 | saint andrews
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint-francois
# Processing Record 14 of Set 3 | whitehorse
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | kirensk
# Processing Record 18 of Set 3 | kysyl-syr
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | asfi
# Processing Record 22 of Set 3 | jiexiu
# Processing Record 23 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 3 | agadez
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | altay
# Processing Record 28 of Set 3 | rawson
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | san andres
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | ndola
# Processing Record 34 of Set 3 | srednekolymsk
# Processing Record 35 of Set 3 | katherine
# Processing Record 36 of Set 3 | punta alta
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | maniitsoq
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | chicama
# Processing Record 41 of Set 3 | deputatskiy
# Processing Record 42 of Set 3 | volga
# Processing Record 43 of Set 3 | hervey bay
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | elban
# Processing Record 46 of Set 3 | oriximina
# Processing Record 47 of Set 3 | kisangani
# Processing Record 48 of Set 3 | thayetmyo
# Processing Record 49 of Set 3 | kinango
# Processing Record 50 of Set 3 | bheramara
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | chinsali
# Processing Record 4 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 5 of Set 4 | jablah
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | ust-kuyga
# Processing Record 8 of Set 4 | phan thiet
# Processing Record 9 of Set 4 | borujan
# City not found. Skipping...
# Processing Record 10 of Set 4 | palmer
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 4 | waingapu
# Processing Record 15 of Set 4 | aksu
# Processing Record 16 of Set 4 | antibes
# Processing Record 17 of Set 4 | kathmandu
# Processing Record 18 of Set 4 | polson
# Processing Record 19 of Set 4 | garissa
# Processing Record 20 of Set 4 | sabaudia
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | manthani
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | puerto lleras
# Processing Record 25 of Set 4 | la paz
# Processing Record 26 of Set 4 | macroom
# Processing Record 27 of Set 4 | amapa
# Processing Record 28 of Set 4 | eirunepe
# Processing Record 29 of Set 4 | chubbuck
# Processing Record 30 of Set 4 | madang
# Processing Record 31 of Set 4 | qitaihe
# Processing Record 32 of Set 4 | kazerun
# Processing Record 33 of Set 4 | brae
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | bolkhov
# Processing Record 37 of Set 4 | yeppoon
# Processing Record 38 of Set 4 | buala
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | novopavlovka
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | canavieiras
# Processing Record 45 of Set 4 | ponta delgada
# Processing Record 46 of Set 4 | san luis
# Processing Record 47 of Set 4 | ondjiva
# Processing Record 48 of Set 4 | nishihara
# Processing Record 49 of Set 4 | bulnes
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | aklavik
# Processing Record 2 of Set 5 | pervomayskoye
# Processing Record 3 of Set 5 | winslow
# Processing Record 4 of Set 5 | byron bay
# Processing Record 5 of Set 5 | goderich
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | flin flon
# Processing Record 9 of Set 5 | sortland
# Processing Record 10 of Set 5 | kambam
# Processing Record 11 of Set 5 | dabat
# Processing Record 12 of Set 5 | lengshuitan
# Processing Record 13 of Set 5 | liverpool
# Processing Record 14 of Set 5 | samarai
# Processing Record 15 of Set 5 | chirongui
# Processing Record 16 of Set 5 | srandakan
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | krasnyy klyuch
# Processing Record 19 of Set 5 | nelson bay
# Processing Record 20 of Set 5 | palmas bellas
# Processing Record 21 of Set 5 | kavieng
# Processing Record 22 of Set 5 | biak
# Processing Record 23 of Set 5 | los llanos de aridane
# Processing Record 24 of Set 5 | amurzet
# Processing Record 25 of Set 5 | daru
# Processing Record 26 of Set 5 | jining
# Processing Record 27 of Set 5 | curumani
# Processing Record 28 of Set 5 | elesbao veloso
# Processing Record 29 of Set 5 | bhinmal
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | cordoba
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | hithadhoo
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | venezuela
# Processing Record 37 of Set 5 | bilma
# Processing Record 38 of Set 5 | kismayo
# Processing Record 39 of Set 5 | sangin
# Processing Record 40 of Set 5 | sinnamary
# Processing Record 41 of Set 5 | corner brook
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 5 | bellavista
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | salinas
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | baykit
# Processing Record 49 of Set 5 | torbay
# Processing Record 50 of Set 5 | nyurba
# Processing Record 1 of Set 6 | hambantota
# Processing Record 2 of Set 6 | kitui
# Processing Record 3 of Set 6 | havre
# Processing Record 4 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 6 | ribeira brava
# Processing Record 6 of Set 6 | vangaindrano
# Processing Record 7 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 6 | tsiroanomandidy
# Processing Record 9 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 6 | aktau
# Processing Record 11 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | wuzhou
# Processing Record 14 of Set 6 | ust-maya
# Processing Record 15 of Set 6 | svetlyy
# Processing Record 16 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 6 | lerik
# Processing Record 18 of Set 6 | nikolskoye
# Processing Record 19 of Set 6 | bubaque
# Processing Record 20 of Set 6 | wajir
# Processing Record 21 of Set 6 | anloga
# Processing Record 22 of Set 6 | qasigiannguit
# Processing Record 23 of Set 6 | energetik
# Processing Record 24 of Set 6 | norman wells
# Processing Record 25 of Set 6 | kirakira
# Processing Record 26 of Set 6 | mashhad
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | borzya
# Processing Record 29 of Set 6 | caxito
# Processing Record 30 of Set 6 | umm kaddadah
# Processing Record 31 of Set 6 | fairbanks
# Processing Record 32 of Set 6 | lagoa
# Processing Record 33 of Set 6 | takoradi
# Processing Record 34 of Set 6 | stuttgart
# Processing Record 35 of Set 6 | santa vitoria do palmar
# Processing Record 36 of Set 6 | jaramana
# City not found. Skipping...
# Processing Record 37 of Set 6 | taoudenni
# Processing Record 38 of Set 6 | tiznit
# Processing Record 39 of Set 6 | kihei
# Processing Record 40 of Set 6 | qeshm
# Processing Record 41 of Set 6 | alta floresta
# Processing Record 42 of Set 6 | boshnyakovo
# Processing Record 43 of Set 6 | thompson
# Processing Record 44 of Set 6 | abu samrah
# Processing Record 45 of Set 6 | yinchuan
# Processing Record 46 of Set 6 | gurupa
# Processing Record 47 of Set 6 | pafos
# Processing Record 48 of Set 6 | honiara
# Processing Record 49 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 6 | toora-khem
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 2 of Set 7 | asau
# Processing Record 3 of Set 7 | batuan
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | menongue
# Processing Record 6 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | de aar
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | saint-louis
# Processing Record 11 of Set 7 | hue
# Processing Record 12 of Set 7 | nouadhibou
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | urucui
# Processing Record 15 of Set 7 | mandera
# Processing Record 16 of Set 7 | sistranda
# Processing Record 17 of Set 7 | siniscola
# Processing Record 18 of Set 7 | mount gambier
# Processing Record 19 of Set 7 | maumere
# Processing Record 20 of Set 7 | te anau
# Processing Record 21 of Set 7 | springbok
# Processing Record 22 of Set 7 | huilong
# Processing Record 23 of Set 7 | acari
# Processing Record 24 of Set 7 | kruisfontein
# Processing Record 25 of Set 7 | isangel
# Processing Record 26 of Set 7 | gimli
# Processing Record 27 of Set 7 | inuvik
# Processing Record 28 of Set 7 | tikhvin
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | mana
# Processing Record 31 of Set 7 | portland
# Processing Record 32 of Set 7 | gunjur
# Processing Record 33 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 7 | hare bay
# Processing Record 35 of Set 7 | alyangula
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | mbuji-mayi
# Processing Record 38 of Set 7 | san cristobal
# Processing Record 39 of Set 7 | dauriya
# Processing Record 40 of Set 7 | columbus
# Processing Record 41 of Set 7 | hamilton
# Processing Record 42 of Set 7 | kaputa
# Processing Record 43 of Set 7 | walvis bay
# Processing Record 44 of Set 7 | shediac
# Processing Record 45 of Set 7 | rudnichnyy
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | lexington
# Processing Record 48 of Set 7 | otane
# Processing Record 49 of Set 7 | hammerfest
# Processing Record 50 of Set 7 | igrim
# Processing Record 1 of Set 8 | drayton valley
# Processing Record 2 of Set 8 | manaus
# Processing Record 3 of Set 8 | mareeba
# Processing Record 4 of Set 8 | atikokan
# Processing Record 5 of Set 8 | severo-kurilsk
# Processing Record 6 of Set 8 | namatanai
# Processing Record 7 of Set 8 | vertientes
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | hay river
# Processing Record 10 of Set 8 | smolenka
# Processing Record 11 of Set 8 | luau
# Processing Record 12 of Set 8 | saint george
# Processing Record 13 of Set 8 | cowra
# Processing Record 14 of Set 8 | monroe
# Processing Record 15 of Set 8 | abha
# Processing Record 16 of Set 8 | georgetown
# Processing Record 17 of Set 8 | corn island
# Processing Record 18 of Set 8 | grindavik
# Processing Record 19 of Set 8 | haines junction
# Processing Record 20 of Set 8 | buncrana
# Processing Record 21 of Set 8 | lavrentiya
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | blackwater
# Processing Record 24 of Set 8 | pevek
# Processing Record 25 of Set 8 | najran
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | mandalgovi
# Processing Record 28 of Set 8 | makakilo city
# Processing Record 29 of Set 8 | ancud
# Processing Record 30 of Set 8 | presidencia roque saenz pena
# Processing Record 31 of Set 8 | nola
# Processing Record 32 of Set 8 | khandyga
# Processing Record 33 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 8 | simbahan
# Processing Record 35 of Set 8 | jinji
# Processing Record 36 of Set 8 | virginia beach
# Processing Record 37 of Set 8 | kavali
# Processing Record 38 of Set 8 | kutum
# Processing Record 39 of Set 8 | iranshahr
# Processing Record 40 of Set 8 | denia
# Processing Record 41 of Set 8 | lubana
# Processing Record 42 of Set 8 | tomatlan
# Processing Record 43 of Set 8 | viedma
# Processing Record 44 of Set 8 | chabahar
# Processing Record 45 of Set 8 | estelle
# Processing Record 46 of Set 8 | meulaboh
# Processing Record 47 of Set 8 | ambilobe
# Processing Record 48 of Set 8 | tonstad
# Processing Record 49 of Set 8 | diadema
# Processing Record 50 of Set 8 | troy
# Processing Record 1 of Set 9 | kieta
# Processing Record 2 of Set 9 | puerto del rosario
# Processing Record 3 of Set 9 | sawakin
# Processing Record 4 of Set 9 | nyakahanga
# Processing Record 5 of Set 9 | suining
# Processing Record 6 of Set 9 | xapuri
# Processing Record 7 of Set 9 | pontes e lacerda
# Processing Record 8 of Set 9 | novaya ladoga
# Processing Record 9 of Set 9 | ribeira grande
# Processing Record 10 of Set 9 | lastoursville
# Processing Record 11 of Set 9 | gravdal
# Processing Record 12 of Set 9 | nara
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | along
# Processing Record 16 of Set 9 | sterlitamak
# Processing Record 17 of Set 9 | kati
# Processing Record 18 of Set 9 | harlingen
# Processing Record 19 of Set 9 | havre-saint-pierre
# Processing Record 20 of Set 9 | kalmunai
# Processing Record 21 of Set 9 | marystown
# Processing Record 22 of Set 9 | salalah
# Processing Record 23 of Set 9 | plettenberg bay
# Processing Record 24 of Set 9 | shache
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | sola
# Processing Record 27 of Set 9 | lesnoy
# Processing Record 28 of Set 9 | zaozerne
# Processing Record 29 of Set 9 | steinfurt
# Processing Record 30 of Set 9 | bathsheba
# Processing Record 31 of Set 9 | forbesganj
# Processing Record 32 of Set 9 | port macquarie
# Processing Record 33 of Set 9 | camacha
# Processing Record 34 of Set 9 | new glasgow
# Processing Record 35 of Set 9 | tuzha
# Processing Record 36 of Set 9 | lulea
# Processing Record 37 of Set 9 | rio gallegos
# Processing Record 38 of Set 9 | barbacena
# Processing Record 39 of Set 9 | quesnel
# Processing Record 40 of Set 9 | armidale
# Processing Record 41 of Set 9 | yumen
# Processing Record 42 of Set 9 | ibotirama
# Processing Record 43 of Set 9 | coahuayana
# Processing Record 44 of Set 9 | ballina
# Processing Record 45 of Set 9 | xiaoshi
# Processing Record 46 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 9 | waipawa
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | mazara del vallo
# Processing Record 1 of Set 10 | algeciras
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | ngunguru
# Processing Record 4 of Set 10 | port blair
# Processing Record 5 of Set 10 | kaitangata
# Processing Record 6 of Set 10 | gamba
# Processing Record 7 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | sembakung
# Processing Record 10 of Set 10 | permatang kuching
# Processing Record 11 of Set 10 | homer
# Processing Record 12 of Set 10 | alofi
# Processing Record 13 of Set 10 | wanganui
# Processing Record 14 of Set 10 | sobolevo
# Processing Record 15 of Set 10 | kashi
# Processing Record 16 of Set 10 | puerto escondido
# Processing Record 17 of Set 10 | kroya
# Processing Record 18 of Set 10 | tymovskoye
# Processing Record 19 of Set 10 | labrea
# Processing Record 20 of Set 10 | eyl
# Processing Record 21 of Set 10 | khasan
# Processing Record 22 of Set 10 | tobol
# Processing Record 23 of Set 10 | omurtag
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | ranong
# Processing Record 26 of Set 10 | banda aceh
# Processing Record 27 of Set 10 | fort nelson
# Processing Record 28 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 29 of Set 10 | bergen
# Processing Record 30 of Set 10 | sept-iles
# Processing Record 31 of Set 10 | aasiaat
# Processing Record 32 of Set 10 | ormara
# Processing Record 33 of Set 10 | novyy urengoy
# Processing Record 34 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 10 | chimore
# Processing Record 36 of Set 10 | huarmey
# Processing Record 37 of Set 10 | walcourt
# Processing Record 38 of Set 10 | bayburt
# Processing Record 39 of Set 10 | axim
# Processing Record 40 of Set 10 | port shepstone
# Processing Record 41 of Set 10 | saint anthony
# Processing Record 42 of Set 10 | hilpoltstein
# Processing Record 43 of Set 10 | prince rupert
# Processing Record 44 of Set 10 | cap-aux-meules
# Processing Record 45 of Set 10 | kidal
# Processing Record 46 of Set 10 | mackay
# Processing Record 47 of Set 10 | sosnovo
# Processing Record 48 of Set 10 | bandipur
# Processing Record 49 of Set 10 | whakatane
# Processing Record 50 of Set 10 | pacific grove
# Processing Record 1 of Set 11 | deming
# Processing Record 2 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 11 | roma
# Processing Record 5 of Set 11 | wanaka
# Processing Record 6 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 11 | maldonado
# Processing Record 8 of Set 11 | richmond
# Processing Record 9 of Set 11 | narsaq
# Processing Record 10 of Set 11 | nizhniy kuranakh
# Processing Record 11 of Set 11 | ponta do sol
# Processing Record 12 of Set 11 | puerto quijarro
# Processing Record 13 of Set 11 | masuguru
# Processing Record 14 of Set 11 | basiad
# Processing Record 15 of Set 11 | mitchell
# Processing Record 16 of Set 11 | redlands
# Processing Record 17 of Set 11 | beyneu
# Processing Record 18 of Set 11 | praya
# Processing Record 19 of Set 11 | husavik
# Processing Record 20 of Set 11 | tura
# Processing Record 21 of Set 11 | port hedland
# Processing Record 22 of Set 11 | hegang
# Processing Record 23 of Set 11 | jiutai
# Processing Record 24 of Set 11 | esso
# Processing Record 25 of Set 11 | sicamous
# Processing Record 26 of Set 11 | zhigansk
# Processing Record 27 of Set 11 | savinka
# Processing Record 28 of Set 11 | faya
# Processing Record 29 of Set 11 | tabou
# Processing Record 30 of Set 11 | vila franca do campo
# Processing Record 31 of Set 11 | turochak
# Processing Record 32 of Set 11 | maple creek
# Processing Record 33 of Set 11 | yatou
# Processing Record 34 of Set 11 | bushehr
# Processing Record 35 of Set 11 | umea
# Processing Record 36 of Set 11 | megion
# Processing Record 37 of Set 11 | araxa
# Processing Record 38 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 11 | constantine
# Processing Record 40 of Set 11 | yar-sale
# Processing Record 41 of Set 11 | vyshneve
# Processing Record 42 of Set 11 | mindelo
# Processing Record 43 of Set 11 | beauchamps
# Processing Record 44 of Set 11 | muros
# Processing Record 45 of Set 11 | sorland
# Processing Record 46 of Set 11 | shelburne
# Processing Record 47 of Set 11 | oxford
# Processing Record 48 of Set 11 | aviles
# Processing Record 49 of Set 11 | camopi
# Processing Record 50 of Set 11 | zaoyang
# Processing Record 1 of Set 12 | raga
# Processing Record 2 of Set 12 | churachandpur
# Processing Record 3 of Set 12 | erenhot
# Processing Record 4 of Set 12 | bireun
# Processing Record 5 of Set 12 | eydhafushi
# Processing Record 6 of Set 12 | xining
# Processing Record 7 of Set 12 | tuatapere
# Processing Record 8 of Set 12 | tevaitoa
# Processing Record 9 of Set 12 | wanning
# Processing Record 10 of Set 12 | omsukchan
# Processing Record 11 of Set 12 | madera
# Processing Record 12 of Set 12 | filingue
# Processing Record 13 of Set 12 | dalvik
# Processing Record 14 of Set 12 | mersing
# Processing Record 15 of Set 12 | quatre cocos
# Processing Record 16 of Set 12 | xai-xai
# Processing Record 17 of Set 12 | aranos
# Processing Record 18 of Set 12 | las vegas
# Processing Record 19 of Set 12 | karpinsk
# Processing Record 20 of Set 12 | aksarka
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | aksarayskiy
# Processing Record 23 of Set 12 | mehamn
# Processing Record 24 of Set 12 | norsup
# Processing Record 25 of Set 12 | saurimo
# Processing Record 26 of Set 12 | bereda
# Processing Record 27 of Set 12 | taitung
# Processing Record 28 of Set 12 | yanam
# Processing Record 29 of Set 12 | hualmay
# Processing Record 30 of Set 12 | salinopolis
# Processing Record 31 of Set 12 | balakhninskiy
# Processing Record 32 of Set 12 | severo-yeniseyskiy
# Processing Record 33 of Set 12 | dondo
# Processing Record 34 of Set 12 | chamrajnagar
# Processing Record 35 of Set 12 | khani
# Processing Record 36 of Set 12 | saint-pierre
# Processing Record 37 of Set 12 | sembe
# Processing Record 38 of Set 12 | marrakesh
# Processing Record 39 of Set 12 | azul
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | unity
# Processing Record 42 of Set 12 | cockburn town
# Processing Record 43 of Set 12 | mitu
# Processing Record 44 of Set 12 | sambava
# Processing Record 45 of Set 12 | igarka
# Processing Record 46 of Set 12 | trinidad
# Processing Record 47 of Set 12 | kaeo
# Processing Record 48 of Set 12 | strezhevoy
# Processing Record 49 of Set 12 | townsville
# Processing Record 50 of Set 12 | witu
# Processing Record 1 of Set 13 | kavaratti
# Processing Record 2 of Set 13 | rio grande
# Processing Record 3 of Set 13 | manggar
# Processing Record 4 of Set 13 | talnakh
# Processing Record 5 of Set 13 | westport
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | boyabat
# Processing Record 8 of Set 13 | kawalu
# Processing Record 9 of Set 13 | chauk
# Processing Record 10 of Set 13 | dunedin
# Processing Record 11 of Set 13 | twentynine palms
# Processing Record 12 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 13 | jawa
# Processing Record 14 of Set 13 | altagracia de orituco
# Processing Record 15 of Set 13 | kimry
# Processing Record 16 of Set 13 | shitanjing
# Processing Record 17 of Set 13 | torit
# Processing Record 18 of Set 13 | tateyama
# Processing Record 19 of Set 13 | vanimo
# Processing Record 20 of Set 13 | kiama
# Processing Record 21 of Set 13 | likhoslavl
# Processing Record 22 of Set 13 | vanavara
# Processing Record 23 of Set 13 | kabwe
# Processing Record 24 of Set 13 | new london
# Processing Record 25 of Set 13 | numata
# Processing Record 26 of Set 13 | calvinia
# Processing Record 27 of Set 13 | nuuk
# Processing Record 28 of Set 13 | porvoo
# Processing Record 29 of Set 13 | jalu
# Processing Record 30 of Set 13 | peachland
# Processing Record 31 of Set 13 | brightwater
# Processing Record 32 of Set 13 | honningsvag
# Processing Record 33 of Set 13 | nizhniy tsasuchey
# Processing Record 34 of Set 13 | lake city
# Processing Record 35 of Set 13 | buchanan
# Processing Record 36 of Set 13 | cortez
# Processing Record 37 of Set 13 | poshekhonye
# Processing Record 38 of Set 13 | linhares
# Processing Record 39 of Set 13 | kedrovyy
# Processing Record 40 of Set 13 | malkara
# Processing Record 41 of Set 13 | port hardy
# Processing Record 42 of Set 13 | koppal
# Processing Record 43 of Set 13 | mangochi
# Processing Record 44 of Set 13 | urumqi
# Processing Record 45 of Set 13 | jurm
# Processing Record 46 of Set 13 | renukut
# Processing Record 47 of Set 13 | port hawkesbury
# Processing Record 48 of Set 13 | gangapur
# Processing Record 49 of Set 13 | porto novo
# Processing Record 50 of Set 13 | seabra
# Processing Record 1 of Set 14 | wellington
# Processing Record 2 of Set 14 | moindou
# Processing Record 3 of Set 14 | atambua
# Processing Record 4 of Set 14 | marfino
# Processing Record 5 of Set 14 | xuddur
# Processing Record 6 of Set 14 | black river
# Processing Record 7 of Set 14 | viransehir
# Processing Record 8 of Set 14 | takhtamygda
# Processing Record 9 of Set 14 | mecca
# Processing Record 10 of Set 14 | zwedru
# Processing Record 11 of Set 14 | deloraine
# Processing Record 12 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 14 | visnagar
# Processing Record 14 of Set 14 | sorong
# Processing Record 15 of Set 14 | tanout
# Processing Record 16 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 17 of Set 14 | turbat
# Processing Record 18 of Set 14 | thinadhoo
# Processing Record 19 of Set 14 | anori
# Processing Record 20 of Set 14 | bakchar
# Processing Record 21 of Set 14 | xinzhou
# Processing Record 22 of Set 14 | tabuk
# Processing Record 23 of Set 14 | gorontalo
# Processing Record 24 of Set 14 | diksmuide
# Processing Record 25 of Set 14 | usinsk
# Processing Record 26 of Set 14 | ekhabi
# Processing Record 27 of Set 14 | ahtopol
# Processing Record 28 of Set 14 | kloulklubed
# Processing Record 29 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | ust-tarka
# Processing Record 31 of Set 14 | shizunai
# Processing Record 32 of Set 14 | central point
# Processing Record 33 of Set 14 | boyolangu
# Processing Record 34 of Set 14 | richards bay
# Processing Record 35 of Set 14 | moerai
# Processing Record 36 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 14 | weligama
# Processing Record 38 of Set 14 | ilebo
# Processing Record 39 of Set 14 | novo aripuana
# Processing Record 40 of Set 14 | fort myers beach
# Processing Record 41 of Set 14 | lima
# Processing Record 42 of Set 14 | sahuaripa
# Processing Record 43 of Set 14 | huzhou
# Processing Record 44 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 14 | riverton
# Processing Record 46 of Set 14 | ossora
# Processing Record 47 of Set 14 | pundaguitan
# Processing Record 48 of Set 14 | darhan
# Processing Record 49 of Set 14 | palora
# Processing Record 50 of Set 14 | belyy yar
# Processing Record 1 of Set 15 | kaduqli
# Processing Record 2 of Set 15 | tazovskiy
# Processing Record 3 of Set 15 | gagra
# Processing Record 4 of Set 15 | sibolga
# Processing Record 5 of Set 15 | morgan city
# Processing Record 6 of Set 15 | osypenko
# Processing Record 7 of Set 15 | evensk
# Processing Record 8 of Set 15 | xinyu
# Processing Record 9 of Set 15 | makat
# Processing Record 10 of Set 15 | oktyabrskiy
# Processing Record 11 of Set 15 | hongjiang
# Processing Record 12 of Set 15 | kovdor
# Processing Record 13 of Set 15 | namioka
# Processing Record 14 of Set 15 | havoysund
# Processing Record 15 of Set 15 | arvika
# Processing Record 16 of Set 15 | umm lajj
# Processing Record 17 of Set 15 | fortuna
# Processing Record 18 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 15 | sioux lookout
# Processing Record 20 of Set 15 | morondava
# Processing Record 21 of Set 15 | the valley
# Processing Record 22 of Set 15 | gidole
# Processing Record 23 of Set 15 | norden
# Processing Record 24 of Set 15 | emerald
# Processing Record 25 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 26 of Set 15 | conceicao da barra
# Processing Record 27 of Set 15 | san quintin
# Processing Record 28 of Set 15 | cooma
# Processing Record 29 of Set 15 | hendek
# Processing Record 30 of Set 15 | kyren
# Processing Record 31 of Set 15 | leningradskiy
# Processing Record 32 of Set 15 | mombetsu
# Processing Record 33 of Set 15 | sinjar
# Processing Record 34 of Set 15 | jibuti
# Processing Record 35 of Set 15 | jardim
# Processing Record 36 of Set 15 | adamus
# Processing Record 37 of Set 15 | yaan
# Processing Record 38 of Set 15 | hidalgo
# Processing Record 39 of Set 15 | varberg
# Processing Record 40 of Set 15 | tessalit
# Processing Record 41 of Set 15 | yashkino
# Processing Record 42 of Set 15 | cuenca
# Processing Record 43 of Set 15 | okha
# Processing Record 44 of Set 15 | tukrah
# Processing Record 45 of Set 15 | kishtwar
# Processing Record 46 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 15 | ostrovnoy
# Processing Record 48 of Set 15 | altamont
# Processing Record 49 of Set 15 | maxixe
# Processing Record 50 of Set 15 | lake jackson
# Processing Record 1 of Set 16 | yarensk
# Processing Record 2 of Set 16 | kennett
# Processing Record 3 of Set 16 | general pico
# Processing Record 4 of Set 16 | naliya
# Processing Record 5 of Set 16 | road town
# Processing Record 6 of Set 16 | russell
# Processing Record 7 of Set 16 | bengkulu
# Processing Record 8 of Set 16 | avera
# Processing Record 9 of Set 16 | puerto maldonado
# Processing Record 10 of Set 16 | riyadh
# Processing Record 11 of Set 16 | fugen
# Processing Record 12 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 16 | semey
# Processing Record 14 of Set 16 | corralillo
# Processing Record 15 of Set 16 | gao
# Processing Record 16 of Set 16 | commerce
# Processing Record 17 of Set 16 | pangody
# Processing Record 18 of Set 16 | pingliang
# Processing Record 19 of Set 16 | iracoubo
# Processing Record 20 of Set 16 | marzuq
# Processing Record 21 of Set 16 | lubao
# Processing Record 22 of Set 16 | solnechnyy
# Processing Record 23 of Set 16 | kijang
# Processing Record 24 of Set 16 | morros
# Processing Record 25 of Set 16 | doha
# Processing Record 26 of Set 16 | barcelos
# Processing Record 27 of Set 16 | oistins
# Processing Record 28 of Set 16 | salym
# Processing Record 29 of Set 16 | rock springs
# Processing Record 30 of Set 16 | sulangan
# Processing Record 31 of Set 16 | valdivia
# Processing Record 32 of Set 16 | el alto
# Processing Record 33 of Set 16 | beruwala
# Processing Record 34 of Set 16 | consett
# Processing Record 35 of Set 16 | bonavista
# Processing Record 36 of Set 16 | bagdarin
# Processing Record 37 of Set 16 | wetter
# Processing Record 38 of Set 16 | mercedes
# Processing Record 39 of Set 16 | pochutla
# Processing Record 40 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 16 | benghazi
# Processing Record 42 of Set 16 | broome
# Processing Record 43 of Set 16 | veselynove
# Processing Record 44 of Set 16 | puyo
# Processing Record 45 of Set 16 | ilinskiy
# Processing Record 46 of Set 16 | duldurga
# Processing Record 47 of Set 16 | kyaikkami
# Processing Record 48 of Set 16 | bentiu
# Processing Record 49 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 16 | amet
# Processing Record 1 of Set 17 | davidson
# Processing Record 2 of Set 17 | manaure
# Processing Record 3 of Set 17 | puerto narino
# Processing Record 4 of Set 17 | kerema
# Processing Record 5 of Set 17 | cap malheureux
# Processing Record 6 of Set 17 | uhlirske janovice
# Processing Record 7 of Set 17 | tongchuan
# Processing Record 8 of Set 17 | khormuj
# City not found. Skipping...
# Processing Record 9 of Set 17 | tavda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 757

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Dikson      RU  73.5069   80.5464      2.32        94         100
# 1      Port Alfred      ZA -33.5906   26.8910     66.18        82          85
# 2         Khatanga      RU  71.9667  102.5000    -11.27        97         100
# 3          Ushuaia      AR -54.8000  -68.3000     56.82        71          75
# 4            Tiksi      RU  71.6872  128.8694    -10.84        91         100
# 5  Bambous Virieux      MU -20.3428   57.7575     73.65        60          40
# 6      Clyde River      CA  70.4692  -68.5914     -5.57        84           0
# 7           Pocone      BR -16.2567  -56.6228     72.34        91          83
# 8           Helena      US  46.5927 -112.0361     36.25        79          99
# 9         Olafsvik      IS  64.8945  -23.7142     44.71        78          71
#
#    Wind Speed Current Description
# 0       21.65     overcast clouds
# 1        4.00     overcast clouds
# 2       13.87     overcast clouds
# 3        4.61       broken clouds
# 4       13.96     overcast clouds
# 5       12.66    scattered clouds
# 6       16.11           clear sky
# 7       10.58       broken clouds
# 8        1.01     overcast clouds
# 9        7.52       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Dikson      RU  73.5069   80.5464      2.32        94         100
# 1      Port Alfred      ZA -33.5906   26.8910     66.18        82          85
# 2         Khatanga      RU  71.9667  102.5000    -11.27        97         100
# 3          Ushuaia      AR -54.8000  -68.3000     56.82        71          75
# 4            Tiksi      RU  71.6872  128.8694    -10.84        91         100
# 5  Bambous Virieux      MU -20.3428   57.7575     73.65        60          40
# 6      Clyde River      CA  70.4692  -68.5914     -5.57        84           0
# 7           Pocone      BR -16.2567  -56.6228     72.34        91          83
# 8           Helena      US  46.5927 -112.0361     36.25        79          99
# 9         Olafsvik      IS  64.8945  -23.7142     44.71        78          71
#
#    Wind Speed Current Description
# 0       21.65     overcast clouds
# 1        4.00     overcast clouds
# 2       13.87     overcast clouds
# 3        4.61       broken clouds
# 4       13.96     overcast clouds
# 5       12.66    scattered clouds
# 6       16.11           clear sky
# 7       10.58       broken clouds
# 8        1.01     overcast clouds
# 9        7.52       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
print(city_data_df.dtypes)
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file ="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
